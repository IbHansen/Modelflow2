# %%
# %matplotlib inline

import pandas as pd
import numpy as np

from modelclass import model
model.widescreen()
# Out:
#         <style id="mf-widescreen">
#             /* Classic Notebook (<=6) */
#             div#notebook-container    { width: 95% !important; }
#             div#menubar-container     { width: 65% !important; }
#             div#maintoolbar-container { width: 99% !important; }
#
#             /* Notebook 7 / JupyterLab */
#             .jp-Notebook,
#             .jp-WindowedPanel-outer,
#             .jp-WindowedPanel-inner { max-width: none !important; }
#             .jp-Notebook .jp-Cell   { max-width: none !important; }
#             /* Some themes constrain the notebook via a centered column: */
#             .jp-NotebookPanel       { max-width: none !important; }
#         </style>

# %% [markdown]
# # Create a Samuleson multiplier accelerator model

# %%
fma   = f'''
gdp = consumption+investment  
consumption = mul * gdp(-1)
investment = acc * (consumption-consumption(-1)) + exo_investment'''
mma = model.from_eq(fma,modelname = 'Accelerator multiplicator model')

# %%
mma.drawmodel()
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.2 (0)
#  -->
# <!-- Title: TD Pages: 1 -->
# <svg width="432pt" height="110pt"
#  viewBox="0.00 0.00 432.00 110.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.472131 0.472131) rotate(0) translate(4 229.5)">
# <title>TD</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-229.5 911,-229.5 911,4 -4,4"/>
# <text xml:space="preserve" text-anchor="middle" x="453.5" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">A_model_graph</text>
# <!-- EXO_INVESTMENT -->
# <g id="node1" class="node">
# <title>EXO_INVESTMENT</title>
# <g id="a_node1"><a xlink:title="EXO_INVESTMENT&#10;Exogen">
# <polygon fill="yellow" stroke="black" points="136.1,-114.5 0,-114.5 0,-78.5 136.1,-78.5 136.1,-114.5"/>
# <g id="a_node1_0"><a xlink:title="EXO_INVESTMENT&#10;Exogen">
# <text xml:space="preserve" text-anchor="start" x="5.8" y="-91.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">EXO_INVESTMENT:</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- INVESTMENT -->
# <g id="node3" class="node">
# <title>INVESTMENT</title>
# <g id="a_node3"><a xlink:title="INVESTMENT&#10;FRML &lt;&gt; INVESTMENT = ACC * (CONSUMPTION&#45;CONSUMPTION(&#45;1)) + EXO_INVESTMENT $">
# <polygon fill="#63b8ff" stroke="black" points="273.7,-87.5 172.1,-87.5 172.1,-51.5 273.7,-51.5 273.7,-87.5"/>
# <g id="a_node3_1"><a xlink:title="INVESTMENT&#10;FRML &lt;&gt; INVESTMENT = ACC * (CONSUMPTION&#45;CONSUMPTION(&#45;1)) + EXO_INVESTMENT $">
# <text xml:space="preserve" text-anchor="start" x="177.9" y="-64.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">INVESTMENT:</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- EXO_INVESTMENT&#45;&gt;INVESTMENT -->
# <g id="edge5" class="edge">
# <title>EXO_INVESTMENT&#45;&gt;INVESTMENT</title>
# <g id="a_edge5"><a xlink:href="bogus" xlink:title="NA">
# <path fill="none" stroke="black" stroke-width="0.5" d="M136.54,-84.58C144.77,-83.13 153.14,-81.65 161.26,-80.21"/>
# <polygon fill="black" stroke="black" stroke-width="0.5" points="161.77,-83.68 171.01,-78.49 160.56,-76.78 161.77,-83.68"/>
# </a>
# </g>
# </g>
# <!-- GDP(&#45;1) -->
# <g id="node2" class="node">
# <title>GDP(&#45;1)</title>
# <g id="a_node2"><a xlink:title="GDP&#10;FRML &lt;&gt; GDP = CONSUMPTION+INVESTMENT &#160;&#160;$">
# <polygon fill="springgreen" stroke="black" points="489.3,-133.5 399.7,-133.5 399.7,-97.5 489.3,-97.5 489.3,-133.5"/>
# <g id="a_node2_2"><a xlink:title="GDP&#10;FRML &lt;&gt; GDP = CONSUMPTION+INVESTMENT &#160;&#160;$">
# <text xml:space="preserve" text-anchor="start" x="405.5" y="-110.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">GDP(&#45;1):GDP</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- CONSUMPTION -->
# <g id="node8" class="node">
# <title>CONSUMPTION</title>
# <g id="a_node8"><a xlink:title="CONSUMPTION&#10;FRML &lt;&gt; CONSUMPTION = MUL * GDP(&#45;1) $">
# <polygon fill="#63b8ff" stroke="black" points="638.9,-133.5 525.3,-133.5 525.3,-97.5 638.9,-97.5 638.9,-133.5"/>
# <g id="a_node8_3"><a xlink:title="CONSUMPTION&#10;FRML &lt;&gt; CONSUMPTION = MUL * GDP(&#45;1) $">
# <text xml:space="preserve" text-anchor="start" x="531.1" y="-110.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">CONSUMPTION:</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- GDP(&#45;1)&#45;&gt;CONSUMPTION -->
# <g id="edge2" class="edge">
# <title>GDP(&#45;1)&#45;&gt;CONSUMPTION</title>
# <g id="a_edge2"><a xlink:href="bogus" xlink:title="NA">
# <path fill="none" stroke="black" stroke-width="0.5" d="M489.53,-115.5C497.46,-115.5 505.9,-115.5 514.32,-115.5"/>
# <polygon fill="black" stroke="black" stroke-width="0.5" points="514.17,-119 524.17,-115.5 514.17,-112 514.17,-119"/>
# </a>
# </g>
# </g>
# <!-- GDP -->
# <g id="node5" class="node">
# <title>GDP</title>
# <g id="a_node5"><a xlink:title="GDP&#10;FRML &lt;&gt; GDP = CONSUMPTION+INVESTMENT &#160;&#160;$">
# <polygon fill="#63b8ff" stroke="black" points="363.7,-133.5 309.7,-133.5 309.7,-97.5 363.7,-97.5 363.7,-133.5"/>
# <g id="a_node5_4"><a xlink:title="GDP&#10;FRML &lt;&gt; GDP = CONSUMPTION+INVESTMENT &#160;&#160;$">
# <text xml:space="preserve" text-anchor="start" x="321.32" y="-110.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">GDP:</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- INVESTMENT&#45;&gt;GDP -->
# <g id="edge8" class="edge">
# <title>INVESTMENT&#45;&gt;GDP</title>
# <g id="a_edge8"><a xlink:href="bogus" xlink:title="NA">
# <path fill="none" stroke="black" stroke-width="0.5" d="M268.73,-87.94C278.92,-92.14 289.62,-96.54 299.4,-100.57"/>
# <polygon fill="black" stroke="black" stroke-width="0.5" points="297.93,-103.74 308.51,-104.31 300.59,-97.27 297.93,-103.74"/>
# </a>
# </g>
# </g>
# <!-- MUL -->
# <g id="node4" class="node">
# <title>MUL</title>
# <g id="a_node4"><a xlink:title="MUL&#10;Exogen">
# <polygon fill="yellow" stroke="black" points="471.5,-225.5 417.5,-225.5 417.5,-189.5 471.5,-189.5 471.5,-225.5"/>
# <g id="a_node4_5"><a xlink:title="MUL&#10;Exogen">
# <text xml:space="preserve" text-anchor="start" x="427.25" y="-202.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">MUL:</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- MUL&#45;&gt;CONSUMPTION -->
# <g id="edge3" class="edge">
# <title>MUL&#45;&gt;CONSUMPTION</title>
# <g id="a_edge3"><a xlink:href="bogus" xlink:title="NA">
# <path fill="none" stroke="black" stroke-width="0.5" d="M471.97,-189.54C492.92,-175.32 522.4,-155.33 545.44,-139.7"/>
# <polygon fill="black" stroke="black" stroke-width="0.5" points="547.3,-142.66 553.61,-134.15 543.37,-136.87 547.3,-142.66"/>
# </a>
# </g>
# </g>
# <!-- GDP&#45;&gt;GDP(&#45;1) -->
# <g id="edge7" class="edge">
# <title>GDP&#45;&gt;GDP(&#45;1)</title>
# <g id="a_edge7"><a xlink:href="bogus" xlink:title="NA">
# <path fill="none" stroke="black" stroke-width="0.5" d="M364.12,-115.5C371.61,-115.5 380.05,-115.5 388.57,-115.5"/>
# <polygon fill="black" stroke="black" stroke-width="0.5" points="388.56,-119 398.56,-115.5 388.56,-112 388.56,-119"/>
# </a>
# </g>
# </g>
# <!-- CONSUMPTION(&#45;1) -->
# <g id="node6" class="node">
# <title>CONSUMPTION(&#45;1)</title>
# <g id="a_node6"><a xlink:title="CONSUMPTION&#10;FRML &lt;&gt; CONSUMPTION = MUL * GDP(&#45;1) $">
# <polygon fill="springgreen" stroke="black" points="907,-91.5 674.9,-91.5 674.9,-55.5 907,-55.5 907,-91.5"/>
# <g id="a_node6_6"><a xlink:title="CONSUMPTION&#10;FRML &lt;&gt; CONSUMPTION = MUL * GDP(&#45;1) $">
# <text xml:space="preserve" text-anchor="start" x="680.7" y="-68.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">CONSUMPTION(&#45;1):CONSUMPTION</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- CONSUMPTION(&#45;1)&#45;&gt;INVESTMENT -->
# <g id="edge1" class="edge">
# <title>CONSUMPTION(&#45;1)&#45;&gt;INVESTMENT</title>
# <g id="a_edge1"><a xlink:href="bogus" xlink:title="NA">
# <path fill="none" stroke="black" stroke-width="0.5" d="M674.62,-71.44C588.87,-70.01 468.98,-68.24 363.7,-67.5 339.7,-67.33 333.7,-67.22 309.7,-67.5 301.53,-67.6 292.92,-67.74 284.44,-67.91"/>
# <polygon fill="black" stroke="black" stroke-width="0.5" points="284.48,-64.41 274.56,-68.12 284.63,-71.41 284.48,-64.41"/>
# </a>
# </g>
# </g>
# <!-- ACC -->
# <g id="node7" class="node">
# <title>ACC</title>
# <g id="a_node7"><a xlink:title="ACC&#10;Exogen">
# <polygon fill="yellow" stroke="black" points="95.05,-60.5 41.05,-60.5 41.05,-24.5 95.05,-24.5 95.05,-60.5"/>
# <g id="a_node7_7"><a xlink:title="ACC&#10;Exogen">
# <text xml:space="preserve" text-anchor="start" x="52.3" y="-37.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">ACC:</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- ACC&#45;&gt;INVESTMENT -->
# <g id="edge4" class="edge">
# <title>ACC&#45;&gt;INVESTMENT</title>
# <g id="a_edge4"><a xlink:href="bogus" xlink:title="NA">
# <path fill="none" stroke="black" stroke-width="0.5" d="M95.33,-47.14C113.53,-50.36 138.54,-54.78 161.52,-58.84"/>
# <polygon fill="black" stroke="black" stroke-width="0.5" points="160.71,-62.24 171.16,-60.54 161.93,-55.35 160.71,-62.24"

# %% [markdown]
# # A function which generates a dataframe with values

# %%
def get_df(mul=0.9,acc=0.5,gdp=1000,im=200,years=100):
    'Creates imput dataframe to accelerator multiplier model '
    df = pd.DataFrame([[gdp]]*years,index=range(2018,2018+years),columns=['GDP'])
    df.loc[:,'MUL']= mul
    df.loc[:,'ACC']= acc
    df.loc[:,'CONSUMPTION']= gdp*mul
    df.loc[:,'EXO_INVESTMENT']= im
    return df
base = get_df()
base.head()
# Out:
#        GDP  MUL  ACC  CONSUMPTION  EXO_INVESTMENT
# 2018  1000  0.9  0.5        900.0             200
# 2019  1000  0.9  0.5        900.0             200
# 2020  1000  0.9  0.5        900.0             200
# 2021  1000  0.9  0.5        900.0             200
# 2022  1000  0.9  0.5        900.0             200

# %% [markdown]
# # a function to forecast and calculate eigenvalues

# %%
def geteigen(mul,acc,years=30,show=False):
    from copy import copy 
    from modelnewton import newton_diff

    '''Function which creates a Samuelson Multiplier accelerator model, runs it and 
    calculates the eigenvalues for the compaignion matrix in order to evaluate stability'''
    
    first = get_df(mul,acc,years=years)
    base  = mma(first,silent=True)     # Solve the model 
    mma_newton = newton_diff(mma)      # create a newton_diff instance which contains derivatives 
    eig_dic = mma_newton.get_eigenvalues() #  
    display(mma_newton.eigplot());

    if show:
        _ = mma['gdp consumption investment'].plot(top=0.8,title='Values',colrow=3,sharey=False)  # Show the solution
    return  mma_newton

# %% [markdown]
# ## Stability

# %%
geteigen(mul=0.8,acc=0,show=1);

# %% [markdown]
# ## Explosion

# %%
geteigen(mul=0.9,acc=2,show=1);

# %% [markdown]
# ## Exploding oscillations

# %%
geteigen(mul=0.6,acc=2,show=1)

# %% [markdown]
# ## Perpetual oscillations

# %%
geteigen(mul=0.5,acc=2,show=1);

# %% [markdown]
# ## Dampened oscillations

# %%
geteigen(mul=0.7,acc=1,show=1);
